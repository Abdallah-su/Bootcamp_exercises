# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# ### Your answer
# > To-Do:
# Please write your full answer below using complete sentences and clear structure.
#
#
# Loan Default Prediction: Problem Statement and Data Collection Plan
# Problem Statement
# The objective of this project is to predict the likelihood that a loan applicant will default on their payments, where the target variable is a binary classification (default vs. no-default) to support the financial institution's decision on whether to approve or deny a credit application.
# Data Identification and Justification
# To build an effective model, the following data types will be collected:
# • Credit History Data: We will collect historical credit scores and records of past payment behaviors. This data is vital because a history of timely payments is the strongest statistical indicator of future financial responsibility.
# • Demographic and Employment Data: We will gather information regarding the applicant’s current employment status, annual income, and years at their current job. This helps predict loan defaults by establishing the applicant's consistent capacity to generate the cash flow necessary for repayment.
# • Loan Characteristics: We will record specific details of the requested loan, including the total amount, interest rate, and term length. These factors are critical because higher debt-to-income ratios or predatory interest rates significantly increase the mathematical probability of a borrower being unable to meet their obligations.
# Data Sources and Integration
# The data will be obtained from a mix of internal and external sources:
# • Internal Records: We will access the institution’s internal databases to retrieve the applicant's existing transaction history and account balances.
# • Credit Bureaus: We will use secure APIs to integrate official credit reports from agencies like Experian or Equifax to verify external debt and credit scores.
# • Employment Verification Services: We will utilize third-party verification platforms to confirm the accuracy of the income and employment details provided in the application.
# Risks and Constraints
# Developing this model involves several critical risks and governance constraints. We must adhere strictly to privacy regulations such as GDPR or the Fair Credit Reporting Act (FCRA) to ensure the ethical handling of sensitive personal information. Furthermore, we must actively monitor for sampling bias, as historical data may contain systemic biases that could lead to unfair lending practices against specific protected groups. Finally, maintaining data quality is a constant challenge, as incomplete or outdated credit information can lead to inaccurate risk assessments and potential financial loss.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features =  [
    "age","employment_length","credit_score","interest_rate",
    "debt_to_income","total_utilization","home_ownership",
    "purpose","term","state", "application_type","num_open_accounts"]

print("You will now justify the selected features in complete sentences below.")
# Out:
# You will now justify the selected features in complete sentences below.

# %% [markdown]
# ### Your justification
# Age determines the majurity level of the loanee and also energy capacity to be productive to raise the loan.
# Employment length determines whether the loanee can have a continous income flow to the lone within the time frame.
# Credit scores gives hints whether the person will pay the lone.
# Interest rate can handicap the loanee ability to pay if is too high.
# Debt to income can easily influence the payment,thus the lesser the ratio, the higher chances of the payment.
# Total utilization might influence payment if the loanee has used all.
# Home ownership can influence payment because of the fear of forciful selling of the house to clear the loan.
# Purpose of the loan can influence payment, thus if the loan is for production,the likelihood to pay is high than if is for consumption.
# The shorter term of the loan can increase the likelihood to default.
# The country or the state of the loanee affect the likelihod to pay depending the economic state of the State.
# Application type might influence the likelihood to make payment depending on whether is mortgage,credit card or the others.
# Number account might influence the financial burden and might affect the likelihood to default.
#
# > To-Do: Please write complete sentences that justify the relevance of each selected feature.
# #If you excluded any common features, please state your reasons in complete sentences.
# Income and loan amount are excluded because they are embeded in debt to income.
#
# #In two complete sentences, how you would encode
# categorical variables and how you would impute missing values.
# categorical variable will be coded using label coding or one hot coding depending on whether thet have a natural order or not.
# Missing values below 20%, the rows will be dropped, closed to 50% will be replaced with unknown, more than 50% , the column will be dropped.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# ### Your answer
# > To-Do: Please write complete sentences that explain your model choice, your evaluation plan, your approach to class imbalance, and your threshold selection strategy.
#
# Model Choice
# The candidate models for this loan prediction task are Logistic Regression and Random Forest Classifier. Logistic Regression is suitable because it provides clear probability scores that are easy to interpret for regulatory compliance, while Random Forest is effective at capturing complex, non-linear relationships between financial features like income and credit utilization.
# Evaluation Plan
# The evaluation plan involves splitting the data into a 70/30 training and testing set and using k-fold cross-validation to ensure the model generalizes well to unseen applicants. We will report metrics including Accuracy, Precision, Recall, F1-score, and ROC-AUC, as seen in the notebook's output cells. To choose a decision threshold, we will analyze the Precision-Recall trade-off; for instance, a lower threshold might be used if the business priority is to capture as many potential defaults as possible (high Recall), even at the cost of more false alarms.
# Approach to Class Imbalance
# To address class imbalance—where the number of "non-defaults" likely far outweighs "defaults"—we will use stratified splitting during the data split to maintain consistent class proportions. Additionally, we will implement class weights within the model settings or use SMOTE (Synthetic Minority Over-sampling Technique) to give the minority "default" class more influence during the training process.
# Hyperparameter Iteration and Data Leakage
# We will iterate on hyperparameters using GridSearchCV or RandomizedSearchCV to find the optimal settings for the chosen models. To avoid data leakage, we will ensure that all preprocessing steps, such as scaling and imputation, are fit only on the training data and then applied to the test data, ensuring no information from the future "test" set influences the training phase.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below, using full sentences for each scenario.
# 1. Predicting Stock Prices
# Paradigm: Supervised Learning (Regression)
# • Justification: This scenario requires predicting a continuous numerical value based on historical data where the "right answers" (past prices) are known.
# • Input Data: The input data consists of historical time-series features such as previous closing prices, trading volume, and relevant economic indicators.
# • Output: The output is a continuous numerical value representing the predicted future price of a specific stock at a given point in time.
# • Learning Signal: The learning signal is the error (or loss) calculated between the model's predicted price and the actual observed price in the training dataset.
# 2. Organizing a Library of Books
# Paradigm: Unsupervised Learning (Clustering)
# • Justification: The goal is to discover inherent patterns and groupings in the data without using pre-defined category labels.
# • Input Data: The input data includes textual features or metadata from the books, such as word frequency, themes, author style, and publication details.
# • Output: The output is a set of distinct clusters or groupings where books with high similarity are placed together.
# • Learning Signal: The objective is to minimize the mathematical distance between books within the same group while maximizing the distance between different groups.
# 3. Program a Robot to Navigate a Maze
# Paradigm: Reinforcement Learning
# • Justification: This task involves an agent (the robot) learning to make a sequence of decisions through trial and error within an environment to reach a goal.
# • Input Data: The input data consists of the current state of the robot, which includes its position in the maze and sensor readings of its immediate surroundings.
# • Output: The output is a specific action taken by the robot, such as moving forward, turning left, or turning right.
# • Learning Signal: The learning signal is a reward or penalty received from the environment, designed to reinforce actions that lead the robot closer to the exit.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("""Please explain in complete sentences when you would use the elbow method and 
how you would interpret it.""")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below as three paragraphs, one for supervised learning, one for unsupervised learning, and one for reinforcement learning.
#
# Supervised Learning (Classification)
# For the supervised classification model, the evaluation plan consists of splitting the dataset into a training and testing set using cross-validation to ensure that the model generalizes well to new data. I will report metrics such as Accuracy, Precision, Recall, and F1-score, as well as the ROC-AUC to measure the model's ability to distinguish between classes at various thresholds. The key evaluation challenge in this category is managing class imbalance, where the model might appear accurate by simply predicting the majority class while failing to identify the more important minority class.
# Unsupervised Learning (Clustering)
# To evaluate the effectiveness of an unsupervised clustering model, I would measure cluster quality using the Silhouette Score to assess how well-separated the groups are or the Elbow Method to determine the optimal number of clusters. Additionally, I would use diagnostic plots like a dendrogram or a scatter plot of the clustered data to visually inspect the structure and cohesion of the groups. A significant challenge in evaluating unsupervised models is the lack of ground-truth labels, making it difficult to objectively prove that the discovered clusters are meaningful for the specific business context.
# Reinforcement Learning
# In a reinforcement learning scenario, the model's success is measured by tracking the cumulative reward over time to ensure the agent is learning to optimize its actions. I would also monitor convergence to verify that the agent's performance stabilizes and assess the exploration vs. exploitation balance to ensure the agent has sufficiently searched the environment before committing to a specific strategy. A primary evaluation challenge for reinforcement learning is the high sensitivity to the reward function, where a poorly designed signal can lead the agent to learn unintended or "lazy" behaviors to maximize its score
