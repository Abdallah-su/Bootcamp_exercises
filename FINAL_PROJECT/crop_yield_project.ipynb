# %%
import pandas as pd
df_crop_yield = pd.read_csv('yield.csv')
df_pesticide= pd.read_csv('pesticides.csv')
df_rainfall = pd.read_csv('rainfall.csv')
df_temperature = pd.read_csv('temp.csv')

# %%
df_crop_yield.head(20)
# Out:
#    Domain Code Domain  Area Code         Area  Element Code Element  \
# 0           QC  Crops          2  Afghanistan          5419   Yield
# 1           QC  Crops          2  Afghanistan          5419   Yield
# 2           QC  Crops          2  Afghanistan          5419   Yield
# 3           QC  Crops          2  Afghanistan          5419   Yield
# 4           QC  Crops          2  Afghanistan          5419   Yield
# 5           QC  Crops          2  Afghanistan          5419   Yield
# 6           QC  Crops          2  Afghanistan          5419   Yield
# 7           QC  Crops          2  Afghanistan          5419   Yield
# 8           QC  Crops          2  Afghanistan          5419   Yield
# 9           QC  Crops          2  Afghanistan          5419   Yield
# 10          QC  Crops          2  Afghanistan          5419   Yield
# 11          QC  Crops          2  Afghanistan          5419   Yield
# 12          QC  Crops          2  Afghanistan          5419   Yield
# ...

# %%
print(df_crop_yield['Item'].unique())
df_crop_yield[df_crop_yield['Year'] == 1979]
# Out:
# ['Maize' 'Potatoes' 'Rice, paddy' 'Wheat' 'Sorghum' 'Soybeans' 'Cassava'
#  'Yams' 'Sweet potatoes' 'Plantains and others']
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 18             QC  Crops          2  Afghanistan          5419   Yield
# 74             QC  Crops          2  Afghanistan          5419   Yield
# 130            QC  Crops          2  Afghanistan          5419   Yield
# 186            QC  Crops          2  Afghanistan          5419   Yield
# 242            QC  Crops          3      Albania          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56455          QC  Crops        181     Zimbabwe          5419   Yield
# 56511          QC  Crops        181     Zimbabwe          5419   Yield
# 56567          QC  Crops        181     Zimbabwe          5419   Yield
# 56623          QC  Crops        181     Zimbabwe          5419   Yield
# ...

# %%
df_crop_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56717 entries, 0 to 56716
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Domain Code   56717 non-null  object
#  1   Domain        56717 non-null  object
#  2   Area Code     56717 non-null  int64
#  3   Area          56717 non-null  object
#  4   Element Code  56717 non-null  int64
#  5   Element       56717 non-null  object
#  6   Item Code     56717 non-null  int64
#  7   Item          56717 non-null  object
#  8   Year Code     56717 non-null  int64
#  9   Year          56717 non-null  int64
#  10  Unit          56717 non-null  object
#  11  Value         56717 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 5.2+ MB

# %%
df_crop_yield.describe()
# Out:
#           Area Code  Element Code     Item Code     Year Code          Year  \
# count  56717.000000       56717.0  56717.000000  56717.000000  56717.000000
# mean     125.650422        5419.0    111.611651   1989.669570   1989.669570
# std       75.120195           0.0    101.278435     16.133198     16.133198
# min        1.000000        5419.0     15.000000   1961.000000   1961.000000
# 25%       58.000000        5419.0     56.000000   1976.000000   1976.000000
# 50%      122.000000        5419.0    116.000000   1991.000000   1991.000000
# 75%      184.000000        5419.0    125.000000   2004.000000   2004.000000
# max      351.000000        5419.0    489.000000   2016.000000   2016.000000
#
#                 Value
# count    56717.000000
# mean     62094.660084
# std      67835.932856
# min          0.000000
# 25%      15680.000000
# 50%      36744.000000
# 75%      86213.000000
# max    1000000.000000

# %%
df_crop_yield.isnull().sum()
# Out:
# Domain Code     0
# Domain          0
# Area Code       0
# Area            0
# Element Code    0
# Element         0
# Item Code       0
# Item            0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# dtype: int64

# %%
df_crop_yield.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_rainfall.head(20)
# Out:
#            Area  Year average_rain_fall_mm_per_year
# 0   Afghanistan  1985                           327
# 1   Afghanistan  1986                           327
# 2   Afghanistan  1987                           327
# 3   Afghanistan  1989                           327
# 4   Afghanistan  1990                           327
# 5   Afghanistan  1991                           327
# 6   Afghanistan  1992                           327
# 7   Afghanistan  1993                           327
# 8   Afghanistan  1994                           327
# 9   Afghanistan  1995                           327
# 10  Afghanistan  1996                           327
# 11  Afghanistan  1997                           327
# 12  Afghanistan  1998                           327
# 13  Afghanistan  1999                           327
# 14  Afghanistan  2000                           327
# 15  Afghanistan  2001                           327
# 16  Afghanistan  2002                           327
# ...

# %%
df_rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6727 entries, 0 to 6726
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0    Area                          6727 non-null   object
#  1   Year                           6727 non-null   int64
#  2   average_rain_fall_mm_per_year  5953 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 157.8+ KB

# %%
df_rainfall.describe()
# Out:
#               Year
# count  6727.000000
# mean   2001.354839
# std       9.530114
# min    1985.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2010.000000
# max    2017.000000

# %%
df_rainfall.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_rainfall.isnull().sum()
# Out:
#  Area                              0
# Year                               0
# average_rain_fall_mm_per_year    774
# dtype: int64

# %%
df_rainfall=df_rainfall.dropna()

# %%
df_rainfall['average_rain_fall_mm_per_year']=pd.to_numeric(df_rainfall['average_rain_fall_mm_per_year'], errors='coerce')
df_rainfall= df_rainfall.dropna(subset =['average_rain_fall_mm_per_year'])
# Out:
# C:\Users\njedr\AppData\Local\Temp\ipykernel_35264\2008421034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rainfall['average_rain_fall_mm_per_year']=pd.to_numeric(df_rainfall['average_rain_fall_mm_per_year'], errors='coerce')

# %%
df_rainfall['average_rain_fall_mm_per_year']=df_rainfall['average_rain_fall_mm_per_year'].astype('int64')

# %%
df_rainfall.describe()
# Out:
#               Year  average_rain_fall_mm_per_year
# count  5947.000000                    5947.000000
# mean   2001.365899                    1124.743232
# std       9.526335                     786.257365
# min    1985.000000                      51.000000
# 25%    1993.000000                     534.000000
# 50%    2001.000000                    1010.000000
# 75%    2010.000000                    1651.000000
# max    2017.000000                    3240.000000

# %%
df_rainfall.isnull().sum()
# Out:
#  Area                            0
# Year                             0
# average_rain_fall_mm_per_year    0
# dtype: int64

# %%
df_temperature.head(20)
# Out:
#     year        country  avg_temp
# 0   1849  Côte D'Ivoire     25.58
# 1   1850  Côte D'Ivoire     25.52
# 2   1851  Côte D'Ivoire     25.67
# 3   1852  Côte D'Ivoire       NaN
# 4   1853  Côte D'Ivoire       NaN
# 5   1854  Côte D'Ivoire       NaN
# 6   1855  Côte D'Ivoire       NaN
# 7   1856  Côte D'Ivoire     26.28
# 8   1857  Côte D'Ivoire     25.17
# 9   1858  Côte D'Ivoire     25.49
# 10  1859  Côte D'Ivoire     25.92
# 11  1860  Côte D'Ivoire     25.46
# 12  1861  Côte D'Ivoire     25.67
# 13  1862  Côte D'Ivoire     25.17
# 14  1863  Côte D'Ivoire       NaN
# 15  1864  Côte D'Ivoire       NaN
# 16  1865  Côte D'Ivoire       NaN
# 17  1866  Côte D'Ivoire       NaN
# 18  1867  Côte D'Ivoire       NaN
# 19  1868  Côte D'Ivoire       NaN

# %%
df_temperature.describe()
# Out:
#                year      avg_temp
# count  71311.000000  68764.000000
# mean    1905.799007     16.183876
# std       67.102099      7.592960
# min     1743.000000    -14.350000
# 25%     1858.000000      9.750000
# 50%     1910.000000     16.140000
# 75%     1962.000000     23.762500
# max     2013.000000     30.730000

# %%
df_pesticide.head(20)
# Out:
#             Domain     Area Element                Item  Year  \
# 0   Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1   Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2   Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3   Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4   Pesticides Use  Albania     Use  Pesticides (total)  1994
# 5   Pesticides Use  Albania     Use  Pesticides (total)  1995
# 6   Pesticides Use  Albania     Use  Pesticides (total)  1996
# 7   Pesticides Use  Albania     Use  Pesticides (total)  1997
# 8   Pesticides Use  Albania     Use  Pesticides (total)  1998
# 9   Pesticides Use  Albania     Use  Pesticides (total)  1999
# 10  Pesticides Use  Albania     Use  Pesticides (total)  2000
# 11  Pesticides Use  Albania     Use  Pesticides (total)  2001
# 12  Pesticides Use  Albania     Use  Pesticides (total)  2002
# 13  Pesticides Use  Albania     Use  Pesticides (total)  2003
# ...

# %%
df_crop_yield.tail(20)
# Out:
#       Domain Code Domain  Area Code      Area  Element Code Element  \
# 56697          QC  Crops        181  Zimbabwe          5419   Yield
# 56698          QC  Crops        181  Zimbabwe          5419   Yield
# 56699          QC  Crops        181  Zimbabwe          5419   Yield
# 56700          QC  Crops        181  Zimbabwe          5419   Yield
# 56701          QC  Crops        181  Zimbabwe          5419   Yield
# 56702          QC  Crops        181  Zimbabwe          5419   Yield
# 56703          QC  Crops        181  Zimbabwe          5419   Yield
# 56704          QC  Crops        181  Zimbabwe          5419   Yield
# 56705          QC  Crops        181  Zimbabwe          5419   Yield
# 56706          QC  Crops        181  Zimbabwe          5419   Yield
# 56707          QC  Crops        181  Zimbabwe          5419   Yield
# 56708          QC  Crops        181  Zimbabwe          5419   Yield
# 56709          QC  Crops        181  Zimbabwe          5419   Yield
# ...

# %%
print(f'yield shape: {df_crop_yield.shape[0]}')
print(f'pesticide shape: {df_pesticide.shape[0]}')
print(f'rainfall shape: {df_rainfall.shape[0]}')    
print(f'temperature shape: {df_temperature.shape[0]}')
# Out:
# yield shape: 56717
# pesticide shape: 4349
# rainfall shape: 6727
# temperature shape: 71311
