# %% [markdown]
#  Exercise 1: Basic Usage of SciPy
# Task: Import the SciPy library and explore its version.

# %%
import scipy
scipy.__version__
# Out:
# '1.13.1'

# %% [markdown]
# Exercise 2: Descriptive Statistics
# Task: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample Dataset:
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
from scipy import stats
import numpy as np

data = [12, 15, 13, 12, 18, 20, 22, 21]
statictics=stats.describe(data)
avg =stats.tmean(data)
med = np.median(data)
std =stats.tstd(data)
var =stats.tvar(data)
print(f'mean: {avg}, median: {med}, variance: {var}, standard deviation: {std:.2f}')
# Out:
# mean: 16.625, median: 16.5, variance: 17.125, standard deviation: 4.14

# %% [markdown]
# Exercise 3: Understanding Distributions
# Task: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import matplotlib.pyplot as plt
data = stats.norm.rvs(50, 10, 50)
plt.hist(data, edgecolor ='black')
plt.show()

# %% [markdown]
#  Exercise 4: T-Test Application
# Task: Perform a T-test on two sets of randomly generated data.

# %%
np.random.seed(1)
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)
t_test, p_value =stats.ttest_ind(data1, data2)
print(f't-stat :{t_test:.2f}, p-value: {p_value:.2f}')
if p_value <= 0.5:
    print('there is a significant difference between the two data')
else:print('there is no significant difference between the two data')
# Out:
# t-stat :-8.45, p-value: 0.00
# there is a significant difference between the two data

# %% [markdown]
#  Exercise 5: Linear Regression Analysis
# Objective: Apply linear regression to a dataset and interpret the results.
#
# Task: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
# Dataset:
# house_sizes: [50, 70, 80, 100, 120] (in square meters)
# house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
# Questions:
# What is the slope and intercept of the regression line?
# Predict the price of a house that is 90 square meters.
# Interpret the meaning of the slope in the context of housing prices.

# %%
house_sizes=[50, 70, 80, 100, 120]
house_prices= [150000, 200000, 210000, 250000, 280000]
result= stats.linregress(house_sizes, house_prices)
print(result)
print(f'slope :{result.slope:.2f}, intercept: {result.intercept:.2f} currency units')
# Out:
# LinregressResult(slope=np.float64(1828.7671232876712), intercept=np.float64(64383.56164383562), rvalue=np.float64(0.9941945063380758), pvalue=np.float64(0.0005305349938203051), stderr=np.float64(114.26934937207407), intercept_stderr=np.float64(9987.951708594053))
# slope :1828.77, intercept: 64383.56 currency units

# %%
h_size =90
p_predict =result.slope*h_size + result.intercept
print(f'the predicted price for house with size 90 msquared is {p_predict:.2f}')
# Out:
# the predicted price for house with size 90 msquared is228972.60

# %%
print(f"if house price increases by 1 squared meter, the price increase by {result.slope:.2f} currency units")
# Out:
# if house price increases by 1 squared meter, the price increase by 1828.77 currency units

# %% [markdown]
#  Exercise 6: Understanding ANOVA
# Objective: Test understanding of ANOVA and its application.
#
# Task: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
# Dataset:
# fertilizer_1: [5, 6, 7, 6, 5]
# fertilizer_2: [7, 8, 7, 9, 8]
# fertilizer_3: [4, 5, 4, 3, 4]
# Questions:
# Perform an ANOVA test on the given data. What are the F-value and P-value?
# Based on the P-value, do the fertilizers have significantly different effects on plant growth?
# Explain what would happen if the P-value were greater than 0.05.

# %%
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]
f_value, p_value =stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print(f"f-value : {f_value:.2f}, p-value : {p_value:.2f}")
if p_value<0.05:
     print('there is a significant difference in the performances of the three fertilizers')
else: print('there is no significant difference in the performances of the three fertilizers')
print('''

''')
print(''' If the p-value is greater than 0.05, then, there is no significant difference in the 
 in performances of the three fertilizers''')
# Out:
# f-value : 28.53, p-value : 0.00
# there is a significant difference in the performances of the three fertilizers
#
#
#
#  If the p-value is greater than 0.05, then, there is no significant difference in the
#  in performances of the three fertilizers

# %% [markdown]
#  Exercise 8: Correlation Coefficients (Optional)
# Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.
# Example in code: data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})
gi
r, p_value =stats.pearsonr(data['age'], data['income'])
r

print(f'Pearson results: r = {r:.2f}, p-value = {p_value:.2f}')
r =np.abs(r)
if r == 1.0: 
    print('perfect positive linear/monotonic relationship between age and income')
elif r == 0.0: 
    print('no linear/monotonic relationship between age and income')
elif r == -1.0: 
    print('perfect negative linear/monotonic relationship between age and income')
elif r > 0.7: 
    print('strong relationship between age and income')
elif 0.3 < r < 0.7: 
    print('moderate relationship between age and income')
elif r < 0.3: 
    print('weak relationship between age and income')
if p_value <0.05:
    print('Since the p_value is < 0.05, the relationship between age and income is significant')
else : print('Since the p_value is > 0.05, the relationship between age and income is not significant')
rho, p_value = stats.spearmanr(data['age'], data['income'])
print(f'spearman results: rho = {rho:.2f}, p_value = {p_value:.2f}')
# Out:
# Pearson results: r = 1.00, p-value = 0.00
# strong relationship between age and income
# Since the p_value is < 0.05, the relationship between age and income is significant
# spearman results: rho = 1.00, p_value = 0.00
